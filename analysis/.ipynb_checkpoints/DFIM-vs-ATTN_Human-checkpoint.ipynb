# %% [markdown]
# ## Imports

# %%
import pandas as pd
import sys

sys.path.insert(0,'../satori')

from postprocess import *

# %% [markdown]
# ### Load the interaction results

# %%
exp_name = "../results/human_promoters/complex/E1_2/"
satori_file = "Interactions_SATORI/interactions_summary_attnLimit-0.20875070544616126.txt"
fis_file = "Interactions_FIS/interactions_summary_attnLimit-0.txt"

output = exp_name

# %%
# For SATORI based interactions
df_A = pd.read_csv(exp_name + satori_file,sep='\t')
#df_A = pd.read_csv('../Results/Human_Promoter_Analysis_euclidean_v8d/Interactions_SATORI/interactions_summary_attnLimit-0.04.txt',sep='\t')

# For FIS based interactions
df_B = pd.read_csv(exp_name + fis_file,sep='\t')
#df_B = pd.read_csv('../Results/Human_Promoter_Analysis_euclidean_v8_fixed/Interactions_FIS/interactions_summary_attnLimit-0.txt',sep='\t')

# %% [markdown]
# ### Load the annotation file

# %%
fhd_file = "/s/jawar/p/nobackup/altsplice1/fahad/DeepLearning/Basset_Splicing_IR-iDiffIR/Analysis_For_none_network-typeB_lotus_posThresh-0.60/MEME_analysis/Homo_sapiens_2019_01_14_4_17_pm/TF_Information_all_motifs.txt"
df_annotate = pd.read_csv(fhd_file,sep='\t')

# %%
df_A
# Out:
#            filter_interaction  example_no      motif1   motif1_qval  \
# 0          filter4<-->filter5        1190  M1605_1.02  2.204730e-03
# 1          filter4<-->filter6        1191  M1605_1.02  2.204730e-03
# 2         filter4<-->filter11        1196  M1605_1.02  2.204730e-03
# 3         filter4<-->filter14        1199  M1605_1.02  2.204730e-03
# 4         filter4<-->filter18        1203  M1605_1.02  2.204730e-03
# ...                       ...         ...         ...           ...
# 12054  filter293<-->filter295       44830  M0608_1.02  8.426780e-07
# 12055  filter293<-->filter299       44834  M0608_1.02  8.426780e-07
# 12056  filter294<-->filter295       44835  M1605_1.02  4.144660e-03
# 12057  filter294<-->filter299       44839  M1605_1.02  4.144660e-03
# 12058  filter295<-->filter299       44843  M0891_1.02  1.168100e-03
#
#            motif2  motif2_qval  mean_distance  mean_distance_bg  num_obs  \
# 0      M1605_1.02     0.012199          246.0             162.0    134.0
# 1      M0891_1.02     0.002610          192.0              12.0    102.0
# 2      M0408_1.02     0.019894           96.0             240.0    109.0
# 3      M0632_1.02     0.000570          294.0             456.0    106.0
# 4      M0607_1.02     0.004220           24.0             276.0    129.0
# ...           ...          ...            ...               ...      ...
# 12054  M0891_1.02     0.001168          402.0              12.0    143.0
# 12055  M0607_1.02     0.003744            6.0             204.0    134.0
# 12056  M0891_1.02     0.001168          282.0             234.0    106.0
# 12057  M0607_1.02     0.003744            6.0              18.0     99.0
# 12058  M0607_1.02     0.003744          126.0             234.0    180.0
#
#        num_obs_bg      pval  adjusted_pval
# 0           221.0  0.309246       0.561592
# 1           160.0  0.086148       0.282432
# 2           149.0  0.203563       0.450542
# 3           195.0  0.079728       0.270925
# 4           143.0  0.230588       0.481243
# ...           ...       ...            ...
# 12054       168.0  0.428349       0.665461
# 12055       146.0  0.229108       0.479703
# 12056       168.0  0.133284       0.358076
# 12057       140.0  0.458685       0.689402
# 12058       270.0  0.243581       0.494544
#
# [12059 rows x 12 columns]

# %%
filter_data_on_thresholds(df_B, motifA_pval_cutoff=0.05, motifB_pval_cutoff=0.05).shape
# Out:
# (0, 12)

# %% [markdown]
# ### Pre-process the interactions

# %%
ATTN = preprocess_for_comparison(df_A, annotation_df=df_annotate)
DFIM = preprocess_for_comparison(df_B, annotation_df=df_annotate)
# Out:
# Index(['filter_interaction', 'example_no', 'motif1', 'motif1_qval', 'motif2',
#        'motif2_qval', 'mean_distance', 'mean_distance_bg', 'num_obs',
#        'num_obs_bg', 'pval', 'adjusted_pval', 'TF1', 'TF2'],
#       dtype='object')
#            filter_interaction  example_no      motif1  motif1_qval  \
# 6         filter4<-->filter21        1206  M1605_1.02     0.002205
# 20        filter4<-->filter46        1231  M1605_1.02     0.002205
# 24        filter4<-->filter52        1237  M1605_1.02     0.002205
# 33        filter4<-->filter68        1253  M1605_1.02     0.002205
# 62       filter4<-->filter121        1306  M1605_1.02     0.002205
# ...                       ...         ...         ...          ...
# 11836  filter253<-->filter272       43787  M1110_1.02     0.035241
# 11841  filter253<-->filter282       43797  M1110_1.02     0.035241
# 11875  filter256<-->filter272       43919  M0891_1.02     0.011931
# 12007  filter276<-->filter287       44584  M0891_1.02     0.006234
# 12037  filter282<-->filter299       44713  M4459_1.02     0.007306
#
#            motif2  motif2_qval  mean_distance  mean_distance_bg  num_obs  \
# 6      M0404_1.02     0.008267           18.0             156.0    167.0
# 20     M0608_1.02     0.008010          258.0             204.0    165.0
# 24     M0408_1.02     0.034588          228.0              90.0    123.0
# 33     M0408_1.02     0.028421          162.0             306.0    102.0
# 62     M0404_1.02     0.044213          198.0             288.0    150.0
# ...           ...          ...            ...               ...      ...
# 11836  M1007_1.02     0.001207           30.0             258.0    125.0
# 11841  M4459_1.02     0.007306          150.0             306.0    192.0
# 11875  M1007_1.02     0.001207           24.0             306.0    146.0
# 12007  M0607_1.02     0.019489          288.0              96.0     64.0
# 12037  M0607_1.02     0.003744          210.0             366.0    207.0
#
#        num_obs_bg          pval  adjusted_pval   TF1      TF2
# 6           153.0  7.692681e-07       0.000400  SOX1   ZNF202
# 20          197.0  1.230523e-03       0.025598  SOX1      MLL
# 24          165.0  3.067455e-06       0.000869  SOX1  ZKSCAN1
# 33          116.0  1.179992e-03       0.025104  SOX1  ZKSCAN1
# 62          175.0  2.881008e-03       0.042500  SOX1   ZNF202
# ...           ...           ...            ...   ...      ...
# 11836       114.0  1.799985e-03       0.032104  HHEX   HOXA11
# 11841       248.0  7.521037e-04       0.019726  HHEX     EGR1
# 11875       104.0  7.195068e-04       0.019246  TLX2   HOXA11
# 12007       137.0  3.049538e-03       0.043928  TLX2    KDM2B
# 12037       244.0  3.258116e-03       0.045720  EGR1    KDM2B
#
# [1061 rows x 14 columns]
# 6         SOX1$\longleftrightarrow$ZNF202
# 20           SOX1$\longleftrightarrow$MLL
# 24       SOX1$\longleftrightarrow$ZKSCAN1
# 33       SOX1$\longleftrightarrow$ZKSCAN1
# 62        SOX1$\longleftrightarrow$ZNF202
#                        ...
# 11836     HHEX$\longleftrightarrow$HOXA11
# 11841       HHEX$\longleftrightarrow$EGR1
# 11875     TLX2$\longleftrightarrow$HOXA11
# 12007      TLX2$\longleftrightarrow$KDM2B
# 12037      EGR1$\longleftrightarrow$KDM2B
# Length: 1061, dtype: object

# %%
# Out:
# Index(['filter_interaction', 'example_no', 'motif1', 'motif1_qval', 'motif2',
#        'motif2_qval', 'mean_distance', 'mean_distance_bg', 'num_obs',
#        'num_obs_bg', 'pval', 'adjusted_pval', 'TF1', 'TF2'],
#       dtype='object')
# Empty DataFrame
# Columns: [filter_interaction, example_no, motif1, motif1_qval, motif2, motif2_qval, mean_distance, mean_distance_bg, num_obs, num_obs_bg, pval, adjusted_pval, TF1, TF2]
# Index: []
# Empty DataFrame
# Columns: [filter_interaction, example_no, motif1, motif1_qval, motif2, motif2_qval, mean_distance, mean_distance_bg, num_obs, num_obs_bg, pval, adjusted_pval, TF1, TF2]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 DFIM = preprocess_for_comparison(df_B, annotation_df=df_annotate)
#
# File /s/jawar/i/nobackup/Saira/original/satori/analysis/../satori/postprocess.py:169, in preprocess_for_comparison(dfx, annotation_df, for_arabidopsis, m1_pval, m2_pval)
#     167 print(df)
#     168 print(df.apply(lambda x: x['TF1']+r'$\longleftrightarrow$'+x['TF2'], axis=1))
# --> 169 df['TF_Interaction'] = df.apply(lambda x: x['TF1']+r'$\longleftrightarrow$'+x['TF2'], axis=1)
#     170 df = df[df['TF1']!=df['TF2']]
#     171 df = df.reset_index(drop=True)
#
# File /s/jawar/f/nobackup/Saira/miniconda3/envs/venv3/lib/python3.10/site-packages/pandas/core/frame.py:3970, in DataFrame.__setitem__(self, key, value)
#    3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
# -> 3970     self._set_item_frame_value(key, value)
#    3971 elif (
#    3972     is_list_like(value)
#    3973     and not self.columns.is_unique
#    3974     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3975 ):
#    3976     # Column to set is duplicated
#    3977     self._setitem_array([key], value)
#
# File /s/jawar/f/nobackup/Saira/miniconda3/envs/venv3/lib/python3.10/site-packages/pandas/core/frame.py:4125, in DataFrame._set_item_frame_value(self, key, value)
#    4122     return
#    4124 if len(value.columns) != 1:
# -> 4125     raise ValueError(
#    4126         "Cannot set a DataFrame with multiple columns to the single "
#    4127         f"column {key}"
#    4128     )
#    4130 self[key] = value[value.columns[0]]
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column TF_Interaction

# %%
df_B['TF1'] = df_B['motif1']
df_B['TF2'] = df_B['motif2']
df_B['TF_Interaction'] = df_B.apply(lambda x: x['TF1']+r'$\longleftrightarrow$'+x['TF2'], axis=1)

# %%
ATTN
# Out:
#         filter_interaction  example_no      motif1  motif1_qval      motif2  \
# 0      filter8<-->filter44        1599  M0891_1.02     0.016848  M6442_1.02
# 1     filter22<-->filter44        4168  M0942_1.02     0.002521  M6442_1.02
# 2     filter44<-->filter54        7819  M6442_1.02     0.007496  M0891_1.02
# 3     filter44<-->filter62        7827  M6442_1.02     0.007496  M0942_1.02
# 4     filter44<-->filter70        7835  M6442_1.02     0.007496  M4459_1.02
# 5    filter44<-->filter107        7872  M6442_1.02     0.007496  M1507_1.02
# 6    filter44<-->filter111        7876  M6442_1.02     0.007496  M4604_1.02
# 7    filter44<-->filter117        7882  M6442_1.02     0.007496  M0408_1.02
# 8    filter44<-->filter118        7883  M6442_1.02     0.007496  M1934_1.02
# 9    filter44<-->filter133        7898  M6442_1.02     0.007496  M0607_1.02
# 10   filter44<-->filter145        7910  M6442_1.02     0.007496  M6547_1.02
# 11   filter44<-->filter151        7916  M6442_1.02     0.007496  M1605_1.02
# 12   filter44<-->filter167        7932  M6442_1.02     0.007496  M0408_1.02
# 13   filter44<-->filter174        7939  M6442_1.02     0.007496  M0608_1.02
# 14   filter44<-->filter181        7946  M6442_1.02     0.007496  M6482_1.02
# 15   filter44<-->filter195        7960  M6442_1.02     0.007496  M4604_1.02
# 16  filter133<-->filter195       17750  M0607_1.02     0.000376  M4604_1.02
# 17  filter145<-->filter195       18464  M6547_1.02     0.024718  M4604_1.02
# 18  filter181<-->filter195       19742  M6482_1.02     0.000039  M4604_1.02
#
#     motif2_qval  mean_distance  mean_distance_bg  num_obs  num_obs_bg  \
# 0      0.007496          120.0             240.0    184.0       197.0
# 1      0.007496           36.0             198.0    293.0       181.0
# 2      0.006606           42.0             474.0    176.0       198.0
# 3      0.016708          174.0              30.0    256.0       224.0
# 4      0.000340          294.0             198.0    291.0       149.0
# 5      0.048272          312.0             222.0    269.0       190.0
# 6      0.043167          150.0              66.0    247.0       168.0
# 7      0.012718           90.0             240.0    260.0       198.0
# 8      0.047625           12.0              30.0    241.0       226.0
# 9      0.000376           66.0             474.0    229.0       183.0
# 10     0.024718           90.0             216.0    300.0       182.0
# 11     0.010929           54.0              18.0    228.0       226.0
# 12     0.028277          480.0              66.0    171.0       177.0
# 13     0.030055          180.0             198.0    270.0       211.0
# 14     0.000039           18.0             210.0    256.0       181.0
# 15     0.001089          168.0             246.0    292.0       130.0
# 16     0.001089          102.0             174.0    218.0       105.0
# 17     0.001089          138.0              30.0    278.0       110.0
# 18     0.001089           18.0             234.0    239.0       111.0
#
#             pval  adjusted_pval    TF1      TF2  \
# 0   1.543904e-04   3.791713e-02   TLX2     PURA
# 1   2.482934e-08   4.362789e-05   IRX4     PURA
# 2   3.068973e-06   1.744316e-03   PURA     TLX2
# 3   1.006981e-06   7.704565e-04   PURA     IRX4
# 4   1.389106e-08   3.070388e-05   PURA     EGR1
# 5   2.135838e-06   1.327757e-03   PURA     LCOR
# 6   1.838523e-04   4.252759e-02   PURA   ZNF263
# 7   5.604272e-05   1.640452e-02   PURA  ZKSCAN1
# 8   1.325736e-05   5.071707e-03   PURA     ESR1
# 9   1.452033e-09   3.610662e-06   PURA    KDM2B
# 10  8.603812e-17   1.711556e-12   PURA      ZFX
# 11  3.268323e-06   1.806021e-03   PURA     SOX1
# 12  1.988370e-05   7.191752e-03   PURA  ZKSCAN1
# 13  2.117179e-05   7.520900e-03   PURA      MLL
# 14  2.893166e-08   4.427212e-05   PURA      SP7
# 15  2.672243e-11   1.771964e-07   PURA   ZNF263
# 16  1.603858e-04   3.890921e-02  KDM2B   ZNF263
# 17  2.577605e-06   1.508126e-03    ZFX   ZNF263
# 18  2.091681e-04   4.675259e-02    SP7   ZNF263
#
#                       TF_Interaction   TF1_Family        TF2_Family  \
# 0      TLX2$\longleftrightarrow$PURA  Homeodomain           Unknown
# 1      IRX4$\longleftrightarrow$PURA  Homeodomain           Unknown
# 2      TLX2$\longleftrightarrow$PURA      Unknown       Homeodomain
# 3      IRX4$\longleftrightarrow$PURA      Unknown       Homeodomain
# 4      PURA$\longleftrightarrow$EGR1      Unknown           C2H2 ZF
# 5      PURA$\longleftrightarrow$LCOR      Unknown         Pipsqueak
# 6    PURA$\longleftrightarrow$ZNF263      Unknown           C2H2 ZF
# 7   PURA$\longleftrightarrow$ZKSCAN1      Unknown           C2H2 ZF
# 8      PURA$\longleftrightarrow$ESR1      Unknown  Nuclear receptor
# 9     PURA$\longleftrightarrow$KDM2B      Unknown              CxxC
# 10      PURA$\longleftrightarrow$ZFX      Unknown           C2H2 ZF
# 11     PURA$\longleftrightarrow$SOX1      Unknown               Sox
# 12  PURA$\longleftrightarrow$ZKSCAN1      Unknown           C2H2 ZF
# 13      PURA$\longleftrightarrow$MLL      Unknown              CxxC
# 14      PURA$\longleftrightarrow$SP7      Unknown           C2H2 ZF
# 15   PURA$\longleftrightarrow$ZNF263      Unknown           C2H2 ZF
# 16  KDM2B$\longleftrightarrow$ZNF263         CxxC           C2H2 ZF
# 17    ZFX$\longleftrightarrow$ZNF263      C2H2 ZF           C2H2 ZF
# 18    SP7$\longleftrightarrow$ZNF263      C2H2 ZF           C2H2 ZF
#
#                               Family_Interaction
# 0        Homeodomain$\longleftrightarrow$Unknown
# 1        Homeodomain$\longleftrightarrow$Unknown
# 2        Homeodomain$\longleftrightarrow$Unknown
# 3        Homeodomain$\longleftrightarrow$Unknown
# 4            Unknown$\longleftrightarrow$C2H2 ZF
# 5          Unknown$\longleftrightarrow$Pipsqueak
# 6            Unknown$\longleftrightarrow$C2H2 ZF
# 7            Unknown$\longleftrightarrow$C2H2 ZF
# 8   Unknown$\longleftrightarrow$Nuclear receptor
# 9               Unknown$\longleftrightarrow$CxxC
# 10           Unknown$\longleftrightarrow$C2H2 ZF
# 11               Unknown$\longleftrightarrow$Sox
# 12           Unknown$\longleftrightarrow$C2H2 ZF
# 13              Unknown$\longleftrightarrow$CxxC
# 14           Unknown$\longleftrightarrow$C2H2 ZF
# 15           Unknown$\longleftrightarrow$C2H2 ZF
# 16              CxxC$\longleftrightarrow$C2H2 ZF
# 17           C2H2 ZF$\longleftrightarrow$C2H2 ZF
# 18           C2H2 ZF$\longleftrightarrow$C2H2 ZF

# %% [markdown]
# ### Individual interactions analysis

# %% [markdown]
# #### Get unique interactions per method and their intersection

# %%
ATTN_unique, DFIM_unique, intersected = get_comparison_stats(DFIM, ATTN, intr_type='TF_Interaction')

# %%
ATTN[ATTN['TF_Interaction'] == "SOX1$\longleftrightarrow$TLX2"]
# Out:
#           filter_interaction  example_no      motif1  motif1_qval      motif2  \
# 1         filter1<-->filter8         205  M1605_1.02     0.006896  M0891_1.02
# 6        filter1<-->filter17         214  M1605_1.02     0.006896  M0891_1.02
# 7        filter1<-->filter23         220  M1605_1.02     0.006896  M0891_1.02
# 8        filter1<-->filter24         221  M1605_1.02     0.006896  M0891_1.02
# 16       filter1<-->filter36         233  M1605_1.02     0.006896  M0891_1.02
# ...                      ...         ...         ...          ...         ...
# 4477  filter161<-->filter182       19179  M1605_1.02     0.040274  M0891_1.02
# 4481  filter161<-->filter198       19195  M1605_1.02     0.040274  M0891_1.02
# 4544  filter181<-->filter185       19732  M0891_1.02     0.000009  M1605_1.02
# 4548  filter182<-->filter185       19749  M0891_1.02     0.007582  M1605_1.02
# 4555  filter185<-->filter198       19807  M1605_1.02     0.044528  M0891_1.02
#
#       motif2_qval  mean_distance  mean_distance_bg  num_obs  num_obs_bg  \
# 1        0.001884          150.0             150.0    168.0       170.0
# 6        0.015949            6.0             504.0    112.0       155.0
# 7        0.006944           78.0             204.0    119.0       154.0
# 8        0.000769           84.0             168.0    110.0       128.0
# 16       0.008725          360.0             318.0     93.0        98.0
# ...           ...            ...               ...      ...         ...
# 4477     0.007582           60.0             282.0     23.0        70.0
# 4481     0.012882          282.0              60.0     68.0       161.0
# 4544     0.044528          396.0             210.0    106.0       229.0
# 4548     0.044528          192.0              18.0     23.0        99.0
# 4555     0.012882            6.0             108.0     68.0       231.0
#
#               pval  adjusted_pval   TF1   TF2                 TF_Interaction  \
# 1     4.364537e-15   1.985006e-14  SOX1  TLX2  SOX1$\longleftrightarrow$TLX2
# 6     1.342558e-20   1.368996e-19  SOX1  TLX2  SOX1$\longleftrightarrow$TLX2
# 7     1.481696e-11   4.204058e-11  SOX1  TLX2  SOX1$\longleftrightarrow$TLX2
# 8     5.318846e-14   2.093013e-13  SOX1  TLX2  SOX1$\longleftrightarrow$TLX2
# 16    5.900322e-19   4.698519e-18  SOX1  TLX2  SOX1$\longleftrightarrow$TLX2
# ...            ...            ...   ...   ...                            ...
# 4477  2.165410e-04   2.772148e-04  SOX1  TLX2  SOX1$\longleftrightarrow$TLX2
# 4481  2.129612e-12   6.764409e-12  SOX1  TLX2  SOX1$\longleftrightarrow$TLX2
# 4544  1.862238e-24   3.543420e-23  TLX2  SOX1  SOX1$\longleftrightarrow$TLX2
# 4548  2.103203e-04   2.695462e-04  TLX2  SOX1  SOX1$\longleftrightarrow$TLX2
# 4555  1.338694e-12   4.370867e-12  SOX1  TLX2  SOX1$\longleftrightarrow$TLX2
#
#        TF1_Family   TF2_Family                   Family_Interaction
# 1             Sox  Homeodomain  Sox$\longleftrightarrow$Homeodomain
# 6             Sox  Homeodomain  Sox$\longleftrightarrow$Homeodomain
# 7             Sox  Homeodomain  Sox$\longleftrightarrow$Homeodomain
# 8             Sox  Homeodomain  Sox$\longleftrightarrow$Homeodomain
# 16            Sox  Homeodomain  Sox$\longleftrightarrow$Homeodomain
# ...           ...          ...                                  ...
# 4477          Sox  Homeodomain  Sox$\longleftrightarrow$Homeodomain
# 4481          Sox  Homeodomain  Sox$\longleftrightarrow$Homeodomain
# 4544  Homeodomain          Sox  Sox$\longleftrightarrow$Homeodomain
# 4548  Homeodomain          Sox  Sox$\longleftrightarrow$Homeodomain
# 4555          Sox  Homeodomain  Sox$\longleftrightarrow$Homeodomain
#
# [300 rows x 18 columns]

# %%
DFIM
# Out:
#           filter_interaction  example_no      motif1  motif1_qval      motif2  \
# 0        filter0<-->filter22          21  M0891_1.02     0.032692  M0942_1.02
# 1        filter0<-->filter37          36  M0891_1.02     0.032692  M1605_1.02
# 2        filter0<-->filter39          38  M0891_1.02     0.032692  M0609_1.02
# 3        filter0<-->filter49          48  M0891_1.02     0.032692  M4459_1.02
# 4        filter0<-->filter84          83  M0891_1.02     0.032692  M0608_1.02
# ...                      ...         ...         ...          ...         ...
# 2355  filter186<-->filter197       19819  M0408_1.02     0.004132  M0891_1.02
# 2356  filter186<-->filter198       19820  M0408_1.02     0.004132  M1605_1.02
# 2357  filter189<-->filter195       19850  M1605_1.02     0.029551  M4604_1.02
# 2358  filter194<-->filter195       19885  M0747_1.02     0.007922  M4604_1.02
# 2359  filter195<-->filter197       19891  M4604_1.02     0.001089  M0891_1.02
#
#       motif2_qval  mean_distance  mean_distance_bg  num_obs  num_obs_bg  \
# 0        0.002521          407.0             290.0     84.0       133.0
# 1        0.000048          221.0             168.0     37.0       153.0
# 2        0.013088          194.0             280.0     66.0        99.0
# 3        0.000091          452.0              27.0     70.0       109.0
# 4        0.008948          292.0             517.0     70.0       164.0
# ...           ...            ...               ...      ...         ...
# 2355     0.004329           25.0              12.0    104.0       170.0
# 2356     0.004767          171.0             361.0     46.0       187.0
# 2357     0.001089          278.0             160.0     78.0        63.0
# 2358     0.001089           11.0             149.0     67.0        58.0
# 2359     0.004329           70.0             154.0    130.0        92.0
#
#               pval  adjusted_pval      TF1     TF2  \
# 0     1.831518e-02       0.036724     TLX2    IRX4
# 1     3.810050e-03       0.010334     TLX2    SOX1
# 2     1.858655e-02       0.037121     TLX2   DNMT1
# 3     1.623382e-02       0.033271     TLX2    EGR1
# 4     2.659084e-03       0.007706     TLX2     MLL
# ...            ...            ...      ...     ...
# 2355  5.316382e-08       0.000001  ZKSCAN1    TLX2
# 2356  1.303647e-04       0.000659  ZKSCAN1    SOX1
# 2357  4.925423e-04       0.001941     SOX1  ZNF263
# 2358  4.915539e-03       0.012665    FOXK2  ZNF263
# 2359  3.502633e-05       0.000225   ZNF263    TLX2
#
#                         TF_Interaction   TF1_Family   TF2_Family  \
# 0        TLX2$\longleftrightarrow$IRX4  Homeodomain  Homeodomain
# 1        TLX2$\longleftrightarrow$SOX1  Homeodomain          Sox
# 2       TLX2$\longleftrightarrow$DNMT1  Homeodomain         CxxC
# 3        TLX2$\longleftrightarrow$EGR1  Homeodomain      C2H2 ZF
# 4         TLX2$\longleftrightarrow$MLL  Homeodomain         CxxC
# ...                                ...          ...          ...
# 2355  TLX2$\longleftrightarrow$ZKSCAN1      C2H2 ZF  Homeodomain
# 2356  SOX1$\longleftrightarrow$ZKSCAN1      C2H2 ZF          Sox
# 2357   SOX1$\longleftrightarrow$ZNF263          Sox      C2H2 ZF
# 2358  FOXK2$\longleftrightarrow$ZNF263     Forkhead      C2H2 ZF
# 2359   TLX2$\longleftrightarrow$ZNF263      C2H2 ZF  Homeodomain
#
#                                Family_Interaction
# 0     Homeodomain$\longleftrightarrow$Homeodomain
# 1             Homeodomain$\longleftrightarrow$Sox
# 2            Homeodomain$\longleftrightarrow$CxxC
# 3         Homeodomain$\longleftrightarrow$C2H2 ZF
# 4            Homeodomain$\longleftrightarrow$CxxC
# ...                                           ...
# 2355      Homeodomain$\longleftrightarrow$C2H2 ZF
# 2356              Sox$\longleftrightarrow$C2H2 ZF
# 2357              Sox$\longleftrightarrow$C2H2 ZF
# 2358         C2H2 ZF$\longleftrightarrow$Forkhead
# 2359      Homeodomain$\longleftrightarrow$C2H2 ZF
#
# [2360 rows x 18 columns]

# %%
print(f"DFIM: {len(set(DFIM_unique.keys()))}, SATORI: {len(set(ATTN_unique.keys()))}, Common: {len(intersected)}")
# Out:
# DFIM: 243, SATORI: 15, Common: 11

# %% [markdown]
# #### Comparison plot: individual interactions

# %%
# The order of the arguments determine which method (used for inferring interactions) is being compared to the other
df_res = common_interaction_stats(DFIM_unique, ATTN_unique)

# %%
df_res['in_both'].value_counts()
# Out:
# r    228
# b     15
# Name: in_both, dtype: int64

# %%
plot_interaction_comparison(df_res, first_n=15, xlabel='TF interaction', store_pdf_path=f'{output}/human_satori-vs-fis_TFs.pdf', fig_size=(9,6))

# %% [markdown]
# ### Family interactions analysis

# %% [markdown]
# #### Get unique family interactions per method and their intersection

# %%
ATTN_unique, DFIM_unique, intersected = get_comparison_stats(DFIM, ATTN, intr_type='Family_Interaction')

# %%
print(f"DFIM: {len(set(DFIM_unique.keys()))}, SATORI: {len(set(ATTN_unique.keys()))}, Common: {len(intersected)}")
# Out:
# DFIM: 49, SATORI: 8, Common: 5

# %% [markdown]
# #### Comparison plot: family interactions

# %%
# The order of the arguments determine which method (used for inferring interactions) is being compared to the other
df_res = common_interaction_stats(DFIM_unique, ATTN_unique)

# %%
plot_interaction_comparison(df_res, first_n=10, xlabel='Family interaction', store_pdf_path=f'{output}/human_satori-vs-fis_Fams.pdf', fig_size=(9,6))
